# %%
import nltk
import re
import uuid

# %%
beckett_text = "Well, I prefer that, I must say I prefer that oh you know, oh you, oh I suppose the audience, well well, so there is an audience, it's a public show, you buy your seat and you wait, perhaps it's free, a free show, you take your seat and you wait for it to begin, or perhaps it's compulsory, a compulsory show. You wait for the compulsory show to begin, it takes time, you hear a voice, perhaps it is a recitation, that is the show, someone reciting, selected passages, old favourites, or someone improvising, you can barely hear him, that's the show, you can't leave, you are afraid to leave... you make the best of it, you try and be reasonable, you came too early, here we'd need latin, it's only beginning, it hasn't begun, he'll appear any moment, he'll begin any moment. He is only preluding, clearing his throat, alone in his dressing room, or it's the stage manager giving his instructions, his last recommendations before the curtain rises, that's the show waiting for the show, to the sound of a murmur, you try and be reasonable, perhaps it is not a voice at all, perhaps it's the air ascending, descending, flowing, eddying, seeking exit, finding none, and the spectators, where are they, you didn't notice, in the anguish of waiting, never noticed you were waiting alone, that is the show for the fools in the palace waiting, waiting alone, that is the show, waiting alone, in the restless air, for it to begin, for something to begin, for there to be something else but you, for the power to rise, the courage to leave. You try and be reasonable, perhaps you are blind, probably deaf, the show is over, all is over, but where then is the hand, the helping hand, or merely charitable, or the hired hand, it's a long time coming, to take yours and draw you away, that is the show, free, gratis and for nothing, waiting alone, blind, deaf, you don't know where, you don't know for what, for a hand to come and draw you away, somewhere else, where perhaps it's worse"

# %%
clean_tokens = re.split(r"[ \t\n,\.]+", beckett_text)
dirty_tokens = re.split(r" ", beckett_text)
assert len(dirty_tokens) == len(clean_tokens)

# %% [markdown]
# Dear David,
#
# I want to create a web of relationships in the following passage. The relationships have to link to what has come before – it can only “rewind”, not “fast-forward”. As an example, you can link the “you try and be reasonable” in green back to the “you try and be reasonable” in red, but not vice versa.
#
# Relationships could be in the following categories:
#
# 1. repeated words
# 2. repeated phrases or fragments (eg. “you wait for...” or “you try and be reasonable”)
# 3. words that sound similar (rhyme; half-rhyme; shared syllables or phonemes).

# %% [markdown]
# ## Repeated phrases (no fragments yet)

# %%
# set the minimum size of a phrase to be connected in the text

def find_phrases(clean_tokens, min_phrase_size=5):
    "Find repeated phrases in text and return index of two positions"
    
    visited_keys = dict()
    pairs = set()
    ignored_idxs = set() #is this the best way to do this?
    
    for idx in range(len(clean_tokens)-min_phrase_size):
        if idx in ignored_idxs:
            continue
        key = " ".join(clean_tokens[idx:idx+min_phrase_size])
        # if phrase was visited before
        if key in visited_keys:
            # add arrow from current idx to previous idx
            pairs.add((visited_keys[key], idx))
            # prevent phrases bigger than min size to be added more than once
            fut_lookup_a = min_phrase_size + visited_keys[key]
            fut_lookup_b = min_phrase_size + idx
            while fut_lookup_b < len(clean_tokens) and clean_tokens[fut_lookup_a] == clean_tokens[fut_lookup_b]:
                ignored_idxs.add(fut_lookup_b-min_phrase_size+1)
                fut_lookup_a += 1
                fut_lookup_b += 1
                
        # add new key and position to dictionary
        visited_keys[key] = idx

    return pairs

# %%
def color_phrase(tokens, init_pos, phrase_len, colour):
    tokens[init_pos] = r"{\color{" + colour + r"} " + tokens[init_pos]
    tokens[init_pos+phrase_len-1] = tokens[init_pos+phrase_len-1] + "}"
    return tokens

def add_tikz_mark(tokens, pos):
    pos_adj = pos+phrase_size//2
    orig_token = tokens[pos_adj]
    label = str(uuid.uuid4())[:8]
    #update token inplace
    tokens[pos_adj] = "\n\\tikz[remember picture,inner sep=0pt] \\node (" + label + ")  {};%%\n" + orig_token
    return (tokens, label)

def create_tikz_node(label1, label2):
    return r"""
\begin{tikzpicture}[remember picture,overlay]
  \draw[arrows=->,blue,line width=2pt,opacity=0.20] (""" + label1 + r""") ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(""" + label2 + r""")+(4pt,1.35ex)$);
\end{tikzpicture}"""

# def create_tikz_node(label1, label2):
#     return r"""
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (""" + label1 + r""") -- (""" + label2 + r""");
# \end{tikzpicture}"""

# %%
def build_text(tokens, nodes):
    preamble = r"""\
\documentclass{article}
\usepackage{tikz}
\usetikzlibrary{calc}
\linespread{1.5}


\begin{document} 
    """
    
    postamble = r"""

\end{document}   
    """

    main = " ".join(tokens)
    nodes = "\n".join(nodes)
    
    return "\n".join([preamble, main, nodes, postamble])

# %%
phrase_size = 3
nodes = []
pairs = find_phrases(clean_tokens, phrase_size)

clean_tokens = re.split(r"[ \t\n,\.]+", beckett_text)
dirty_tokens = re.split(r" ", beckett_text)

# create pairs for each arrow
for (pos1, pos2) in pairs:

    #add color to phrases

    tokens_colored_ = color_phrase(dirty_tokens, pos1, phrase_size, "red")
    tokens_colored = color_phrase(tokens_colored_, pos2, phrase_size, "green")
#     tokens_colored = dirty_tokens

    #mark tokens with tikz tags
    tokens_marked_, label1 = add_tikz_mark(tokens_colored, pos1)
    tokens_marked, label2 = add_tikz_mark(tokens_marked_, pos2)
    

    #store the node information
    nodes.append(create_tikz_node(label2, label1))
    

    
print(build_text(tokens_marked, nodes))
# Out:
# \documentclass{article}
# \usepackage{tikz}
# \usetikzlibrary{calc}
# \linespread{1.5}
#
#
# \begin{document}
#
# Well, {\color{red} I
# \tikz[remember picture,inner sep=0pt] \node (7cc445a6)  {};%%
# prefer that,} I must say {\color{green} I
# \tikz[remember picture,inner sep=0pt] \node (90411839)  {};%%
# prefer that} oh you know, oh you, oh I suppose the audience, well well, so there is an audience, it's a public show, you buy {\color{red} your
# \tikz[remember picture,inner sep=0pt] \node (e1636d03)  {};%%
# seat and} you wait, perhaps it's free, a free show, you take {\color{green} your
# \tikz[remember picture,inner sep=0pt] \node (3127d716)  {};%%
# seat and} you wait {\color{red} for
# \tikz[remember picture,inner sep=0pt] \node (08e03e5e)  {};%%
# it to} begin, or perhaps it's compulsory, a compulsory show. You wait for the compulsory show to begin, it takes time, you hear a voice, {\color{red} perhaps
# \tikz[remember picture,inner sep=0pt] \node (07090a0b)  {};%%
# it is} a recitation, {\color{red} that
# \tikz[remember picture,inner sep=0pt] \node (b2dafdef)  {};%%
# is the} show, someone reciting, selected passages, old favourites, or someone improvising, you can barely hear him, {\color{red} that's
# \tikz[remember picture,inner sep=0pt] \node (f5fcf7a8)  {};%%
# the show,} you can't leave, you are afraid to leave... you make the best of it, {\color{red} you
# \tikz[remember picture,inner sep=0pt] \node (f73f6af2)  {};%%
# {\color{red} try
# \tikz[remember picture,inner sep=0pt] \node (fccaa0d2)  {};%%
# and} be} reasonable, you came too early, here we'd need latin, it's only beginning, it hasn't begun, he'll appear any moment, he'll begin any moment. He is only preluding, clearing his throat, alone in his dressing room, or it's the stage manager giving his instructions, his last recommendations before the curtain rises, {\color{green} that's
# \tikz[remember picture,inner sep=0pt] \node (b50c8547)  {};%%
# {\color{red} the
# \tikz[remember picture,inner sep=0pt] \node (e43edb06)  {};%%
# show} waiting} for the show, to the sound of a murmur, {\color{green} you
# \tikz[remember picture,inner sep=0pt] \node (dd63994d)  {};%%
# try and} {\color{red} be
# \tikz[remember picture,inner sep=0pt] \node (3df0a1b3)  {};%%
# reasonable, {\color{green} perhaps}
# \tikz[remember picture,inner sep=0pt] \node (306d7234)  {};%%
# it is} not a voice at all, perhaps it's the air ascending, descending, flowing, eddying, seeking exit, finding none, and the spectators, where are they, you didn't notice, in the anguish of waiting, never noticed you were {\color{red} waiting
# \tikz[remember picture,inner sep=0pt] \node (75a5a7de)  {};%%
# alone, {\color{red} {\color{green} that}
# \tikz[remember picture,inner sep=0pt] \node (df5831d7)  {};%%
#
# \tikz[remember picture,inner sep=0pt] \node (827cd18c)  {};%%
# is the}} show for the fools in the palace waiting, {\color{green} waiting
# \tikz[remember picture,inner sep=0pt] \node (f02e2527)  {};%%
# alone, that} is {\color{green} the
# \tikz[remember picture,inner sep=0pt] \node (6ff611db)  {};%%
# show, waiting} alone, in the restless air, {\color{green} for
# \tikz[remember picture,inner sep=0pt] \node (209be4da)  {};%%
# it {\color{red} to}
# \tikz[remember picture,inner sep=0pt] \node (cb4a0666)  {};%%
# begin, for} something {\color{green} to
# \tikz[remember picture,inner sep=0pt] \node (5c3bdfa2)  {};%%
# begin, for} there to be something else but you, for the power to rise, the courage to leave. You {\color{green} try
# \tikz[remember picture,inner sep=0pt] \node (5532ed19)  {};%%
# and {\color{green} be}
# \tikz[remember picture,inner sep=0pt] \node (93d79efb)  {};%%
# reasonable, perhaps} you are blind, probably deaf, the show is over, all is over, but where then is the hand, the helping hand, or merely charitable, or the hired hand, it's a long time coming, to take yours {\color{red} and
# \tikz[remember picture,inner sep=0pt] \node (4c4a2ad1)  {};%%
# draw you} away, {\color{green} that
# \tikz[remember picture,inner sep=0pt] \node (8a6bb363)  {};%%
# is the} show, free, gratis and for nothing, waiting alone, blind, deaf, {\color{red} you
# \tikz[remember picture,inner sep=0pt] \node (b22b13f3)  {};%%
# don't know} where, {\color{green} you
# \tikz[remember picture,inner sep=0pt] \node (b42c3e95)  {};%%
# don't know} for what, for a hand to come {\color{green} and
# \tikz[remember picture,inner sep=0pt] \node (367ac1ca)  {};%%
# draw you} away, somewhere else, where perhaps it's worse
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (6ff611db) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(e43edb06)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (209be4da) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(08e03e5e)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (b42c3e95) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(b22b13f3)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (5532ed19) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(fccaa0d2)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (93d79efb) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(3df0a1b3)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (b50c8547) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(f5fcf7a8)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (827cd18c) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(b2dafdef)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (5c3bdfa2) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(cb4a0666)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (3127d716) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(e1636d03)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (306d7234) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(07090a0b)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (90411839) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(7cc445a6)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (f02e2527) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(75a5a7de)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (367ac1ca) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(4c4a2ad1)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (dd63994d) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(f73f6af2)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
# \begin{tikzpicture}[remember picture,overlay]
#   \draw[arrows=->,blue,line width=2pt,opacity=0.20] (8a6bb363) ++ (-0.25em,1ex) .. controls ++ (2,0) and ++(0,3) .. ($(df5831d7)+(4pt,1.35ex)$);
# \end{tikzpicture}
#
#
# \end{document}

# %%
dirty_tokens
# Out:
# ['Well,',
#  'I',
#  'prefer',
#  'that,',
#  'I',
#  'must',
#  'say',
#  'I',
#  'prefer',
#  'that',
#  'oh',
#  'you',
#  'know,',
#  'oh',
#  'you,',
#  'oh',
#  'I',
#  'suppose',
#  'the',
#  'audience,',
#  'well',
#  'well,',
#  'so',
#  'there',
#  'is',
#  'an',
#  'audience,',
#  "it's",
#  'a',
#  'public',
#  'show,',
#  'you',
#  'buy',
#  '{\\color{red} your',
#  '{\\color{red} seat',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (dfa39ac1)  {};%%\nand',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (e6b46338)  {};%%\nwait,}',
#  'perhaps}',
#  'perhaps',
#  "it's",
#  'free,',
#  'a',
#  'free',
#  'show,',
#  'you',
#  'take',
#  '{\\color{green} your',
#  '{\\color{green} seat',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (9de66ff0)  {};%%\nand',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (948ae8dd)  {};%%\nwait}',
#  '{\\color{red} for}',
#  '{\\color{red} for',
#  'it',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (5481c57b)  {};%%\nto',
#  'or}',
#  'or',
#  'perhaps',
#  "it's",
#  'compulsory,',
#  'a',
#  'compulsory',
#  'show.',
#  'You',
#  'wait',
#  'for',
#  'the',
#  'compulsory',
#  'show',
#  'to',
#  'begin,',
#  'it',
#  'takes',
#  'time,',
#  'you',
#  'hear',
#  'a',
#  'voice,',
#  'perhaps',
#  'it',
#  'is',
#  'a',
#  'recitation,',
#  '{\\color{red} that',
#  'is',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (530c3c8e)  {};%%\nthe',
#  'someone}',
#  'someone',
#  'reciting,',
#  'selected',
#  'passages,',
#  'old',
#  'favourites,',
#  'or',
#  'someone',
#  'improvising,',
#  'you',
#  'can',
#  'barely',
#  'hear',
#  'him,',
#  "that's",
#  'the',
#  'show,',
#  'you',
#  "can't",
#  'leave,',
#  'you',
#  'are',
#  'afraid',
#  'to',
#  'leave...',
#  'you',
#  'make',
#  'the',
#  'best',
#  'of',
#  'it,',
#  '{\\color{red} you',
#  '{\\color{red} try',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (93cf5071)  {};%%\nand',
#  'you}}',
#  'you}',
#  'you',
#  'came',
#  'too',
#  'early,',
#  'here',
#  "we'd",
#  'need',
#  'latin,',
#  "it's",
#  'only',
#  'beginning,',
#  'it',
#  "hasn't",
#  'begun,',
#  "he'll",
#  'appear',
#  'any',
#  'moment,',
#  "he'll",
#  'begin',
#  'any',
#  'moment.',
#  'He',
#  'is',
#  'only',
#  'preluding,',
#  'clearing',
#  'his',
#  'throat,',
#  'alone',
#  'in',
#  'his',
#  'dressing',
#  'room,',
#  'or',
#  "it's",
#  'the',
#  'stage',
#  'manager',
#  'giving',
#  'his',
#  'instructions,',
#  'his',
#  'last',
#  'recommendations',
#  'before',
#  'the',
#  'curtain',
#  'rises,',
#  "that's",
#  'the',
#  'show',
#  'waiting',
#  'for',
#  'the',
#  'show,',
#  'to',
#  'the',
#  'sound',
#  'of',
#  'a',
#  'murmur,',
#  '{\\color{green} you',
#  '{\\color{red} {\\color{green} try',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (5344408c)  {};%%\n{\\color{red} and',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (d888d124)  {};%%\nperhaps}}',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (d888d124)  {};%%\nperhaps}',
#  'it}',
#  'it',
#  'is',
#  'not',
#  'a',
#  'voice',
#  'at',
#  'all,',
#  'perhaps',
#  "it's",
#  'the',
#  'air',
#  'ascending,',
#  'descending,',
#  'flowing,',
#  'eddying,',
#  'seeking',
#  'exit,',
#  'finding',
#  'none,',
#  'and',
#  'the',
#  'spectators,',
#  'where',
#  'are',
#  'they,',
#  'you',
#  "didn't",
#  'notice,',
#  'in',
#  'the',
#  'anguish',
#  'of',
#  'waiting,',
#  'never',
#  'noticed',
#  'you',
#  'were',
#  '{\\color{red} waiting',
#  '{\\color{red} alone,',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (cbb52e01)  {};%%\n{\\color{red} {\\color{green} that',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (cd164642)  {};%%\nfor}}}',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (cd164642)  {};%%\nfor}}',
#  'for}',
#  'for',
#  'the',
#  'fools',
#  'in',
#  'the',
#  'palace',
#  'waiting,',
#  '{\\color{green} waiting',
#  '{\\color{green} alone,',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (2767896f)  {};%%\n{\\color{green} {\\color{red} that',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (9e613dfd)  {};%%\nwaiting}}}',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (9e613dfd)  {};%%\nwaiting}}',
#  'waiting}',
#  'waiting',
#  'alone,',
#  'in',
#  'the',
#  'restless',
#  'air,',
#  '{\\color{green} for',
#  'it',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (d5740bb1)  {};%%\nto',
#  'for}',
#  'for',
#  'something',
#  'to',
#  'begin,',
#  'for',
#  'there',
#  'to',
#  'be',
#  'something',
#  'else',
#  'but',
#  'you,',
#  'for',
#  'the',
#  'power',
#  'to',
#  'rise,',
#  'the',
#  'courage',
#  'to',
#  'leave.',
#  'You',
#  '{\\color{green} try',
#  '{\\color{green} and',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (98dd7864)  {};%%\nbe',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (2136eeaf)  {};%%\nperhaps}',
#  'you}',
#  'you',
#  'are',
#  'blind,',
#  'probably',
#  'deaf,',
#  'the',
#  'show',
#  'is',
#  'over,',
#  'all',
#  'is',
#  'over,',
#  'but',
#  'where',
#  'then',
#  'is',
#  'the',
#  'hand,',
#  'the',
#  'helping',
#  'hand,',
#  'or',
#  'merely',
#  'charitable,',
#  'or',
#  'the',
#  'hired',
#  'hand,',
#  "it's",
#  'a',
#  'long',
#  'time',
#  'coming,',
#  'to',
#  'take',
#  'yours',
#  '{\\color{red} and',
#  'draw',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (6c0000f8)  {};%%\nyou',
#  '{\\color{green} that}',
#  '{\\color{green} that',
#  'is',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (ab294fae)  {};%%\nthe',
#  'free,}',
#  'free,',
#  'gratis',
#  'and',
#  'for',
#  'nothing,',
#  'waiting',
#  'alone,',
#  'blind,',
#  'deaf,',
#  'you',
#  "don't",
#  'know',
#  'where,',
#  'you',
#  "don't",
#  'know',
#  'for',
#  'what,',
#  'for',
#  'a',
#  'hand',
#  'to',
#  'come',
#  '{\\color{green} and',
#  'draw',
#  '\n\\tikz[remember picture,inner sep=0pt] \\node (80bee026)  {};%%\nyou',
#  'somewhere}',
#  'somewhere',
#  'else,',
#  'where',
#  'perhaps',
#  "it's",
#  'worse']

# %%
print(add_tikz_mark(dirty_tokens[13])[0])
# Out:
# \tikz[remember picture,inner sep=0pt] \node (3825d819)  {};%%
# oh

# %%
p1 = 228
p2 = 241

r1 = " ".join(dirty_tokens[p1-5:p1+min_phrase_size+5])
r2 = " ".join(dirty_tokens[p2-5:p2+min_phrase_size+5])
print(r1)
print()
print(r2)
# Out:
# never noticed you were waiting alone, that is the show for the fools in
# the
#
# in
# the palace waiting, waiting alone, that is the show, waiting alone, in the restless

# %%
"bla" ++ "ble"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-d002b6380ddb> in <module>()
# ----> 1 "bla" ++ "ble"
#
# TypeError: bad operand type for unary +: 'str'
